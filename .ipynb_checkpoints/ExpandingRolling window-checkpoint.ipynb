# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime
import yfinance as yf
import seaborn as sns

# %%
start = datetime.datetime(2020,11,1)
end = datetime.datetime(2023,12,8)
assets = ['MSTR']
MSTR=yf.download(assets, start = start, end = end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
MSTR['Close'].plot(figsize = (14,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Rolling
#
# Rolling with windows size of every 7 days. I will get table, where values are equal to 7 days average.
#
# So first 7 days are null, because u can not calculate avg. Actual day = mean(last 7 days)

# %%
MSTR.rolling(7).mean().head(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2020-11-02         NaN         NaN         NaN         NaN         NaN
# 2020-11-03         NaN         NaN         NaN         NaN         NaN
# 2020-11-04         NaN         NaN         NaN         NaN         NaN
# 2020-11-05         NaN         NaN         NaN         NaN         NaN
# 2020-11-06         NaN         NaN         NaN         NaN         NaN
# 2020-11-09         NaN         NaN         NaN         NaN         NaN
# 2020-11-10  177.497142  180.991429  174.687145  178.499998  178.499998
# 2020-11-11  180.247142  184.418573  178.222859  182.155712  182.155712
# 2020-11-12  183.904286  187.771430  180.774288  184.297141  184.297141
# 2020-11-13  186.122857  189.992859  182.934287  187.117142  187.117142
#
#                    Volume
# Date
# 2020-11-02            NaN
# 2020-11-03            NaN
# 2020-11-04            NaN
# 2020-11-05            NaN
# 2020-11-06            NaN
# 2020-11-09            NaN
# 2020-11-10  162742.857143
# 2020-11-11  163785.714286
# 2020-11-12  176057.142857
# 2020-11-13  183842.857143

# %%
MSTR['Open'].plot()
MSTR.rolling(7).mean()['Close'].plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
MSTR['Open'].plot()
MSTR.rolling(window=30).mean()['Close'].plot(figsize=(15,5))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Expanding window
#
# It is window, where each observation is equal to average of all previous observetions. Meanwhile in rolling window, the window is still moving with the parametr of days, here I take always all values

# %%
MSTR['Open'].plot()
MSTR['Close'].expanding(min_periods=1).mean().plot(figsize=(16,5))
# Out:
# <AxesSubplot:xlabel='Date'>
